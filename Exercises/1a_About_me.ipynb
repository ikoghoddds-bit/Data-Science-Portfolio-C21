# %% [markdown]
# <a href="https://colab.research.google.com/github/ikoghoddds-bit/Data-Science-Portfolio-C21/blob/main/About_me.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Joseph Ikogho**

# %% [markdown]
# ## **Introduction & Bootcamp Goals**
# * **Preferred Name:** Joseph
# * **Why I signed up for this bootcamp:** I joined the CNM Deep Dive Data Science Bootcamp to master the analytical depth of machine learning, statistical modeling, and data engineering. My goal is to combine the structural power of AI automation with advanced data science to build next-generation, data-driven autonomous systems.
# * **Current Professional Focus:** I am a professional in the semiconductor and AI automation industries. Moving forward, I want to bridge the gap between workflow automation and advanced analytics to transform raw organizational data into the underlying fuel that powers intelligent, self-optimizing systems.
#
# ---
#
# ## **Fun Facts & Hypotheticals**
#
# ### ***The 3-App Survival List***
# If my smartphone were wiped clean and I could only preserve three tools to stay secure, organized, and productive, they would be:
# 1. **WhatsApp** (Essential for staying connected instantly with family, colleagues, and community networks)
# 2. **Microsoft Outlook** (Crucial for managing professional communications and schedules)
# 3. **Claude** (My essential AI assistant for real-time problem solving, debugging code, and conceptual brainstorming)
#
# ---
#
# ## **Interests, Hobbies, & Media**
#
# ### **My Favorite Culinary Passions**
# When I am not diving into data pipelines or configuring workflows, I have a massive appreciation for cooking and exploring rich culinary traditions. Here are a few of my favorite traditional dishes to prepare:
# * *Goat Meat Pepper Soup:* A spicy, aromatic, and deeply comforting broth.
# * *Peppered Liver:* A savory, bold dish packed with rich spices.
# * *Moi-Moi:* A classic, steamed bean pudding made utilizing high-quality bean flour.
#
# ### **Quick Reference Table**
# | Category | Favorite Choice | Why I Enjoy It |
# | :--- | :--- | :--- |
# | **Tech Tool** | [n8n Automation](https://n8n.io/) | It allows me to build complex, autonomous AI agent workflows visually. |
# | **Hobby** | Culinary Research | Experimenting with authentic ingredients like African calabash nutmeg and bitter kola. |
# | **Location** | Albuquerque, NM | Home to a great local tech ecosystem and beautiful scenery. |
#
# ---
#
# ## **Something Important To Me**
#
# My ultimate foundation and motivation centers around my family and close relationships. Navigating demanding academic and professional milestones—from intensive graduate engineering programs to advanced data science bootcamps—is entirely driven and sustained by a strong, supportive network at home.
#
# ![Family & Relationships](https://images.pexels.com/photos/4262170/pexels-photo-4262170.jpeg?_gl=1*mosmt*_ga*ODk2NjQyMzEwLjE3ODAzNzg2NDE.*_ga_8JE65Q40S6*czE3ODAzNzg2NDAkbzEkZzEkdDE3ODAzNzg3MTIkajU1JGwwJGgw)

# %% [markdown]
# | Platform | Link |
# | -------- | ------------------------------------ |
# | LinkedIn | [linkedin.com/in/joseph-ikogho](https://www.linkedin.com/in/joseph-ikogho) |
# | GitHub   | [github.com/ikoghoddds-bit](https://github.com/ikoghoddds-bit) |
