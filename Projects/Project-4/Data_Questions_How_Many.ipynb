# %% [markdown]
# Given a table of data, how many ... ?
#
# - columns: 12
#   - identifier columns: 3
#   - target columns: 1 - survived
#     - rows with nulls in each: 0
#   - feature columns: 8
#     - rows with nulls in each:
#       - cabin: 78%
#       - age: 20%
#       - embarcked: < 1%
#   - numerical columns: 5
#     - discreet columns: 3 + 1 target
#       - rows with nulls in each:
#     - continuous columns: 2
#       - rows with nulls in each:
#         - age: 20 %
#   - categorical columns: 4
#     - nominal columns: 2
#       - rows with nulls in each:
#         - embarked : 2
#       - categories in each:
#         - a bunch < 10
#     - ordinal columns:
#       - rows with nulls in each:
#       - categories in each:
#         - a bunch < 10
#   - nested columns:
# - rows: 891
#   - rows with nulls: yes
#   - duplicate rows:
#   - missing rows:
